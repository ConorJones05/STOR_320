# %% [markdown]
# # Week06: Math-related visualization
#
# This jupyter notebook is not required for the weekly class activity 6 submission.

# %% [markdown]
# ## Learning objectives
#
# 1. Introdunction to `matplotlib`
#     - https://matplotlib.org/stable/tutorials/index.html
#
# 2. Different types of plots
#
# 3. Customizing plots
#
# 4. Creating subplots

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Matplotlib
#
# Matplotlib has a "functional" interface via the `pyplot` module for simple interactive use, as well as an object-oriented interface that is useful for more complex graphic creations.

# %% [markdown]
# # Different types of plots
#
# Matplotlib supports various types of plots. We will show some of them and more can be found https://matplotlib.org/stable/plot_types/index.html.
#
# ## Simple line plots
#
# Line plots are often used to track changes over time. By default, Matplotlib creates line plots with `plt.plot()`

# %%
x = np.linspace(0,10, 1000)

# %%
plt.plot(x, np.sin(x));

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x))
plt.savefig("test.png")

# %% [markdown]
# ## Multiple lines in one figure

# %%
x = np.linspace(0,10, 1000)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.plot(x, np.sin(x + np.pi/4));

# %%
fig = plt.figure()
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.plot(x, np.cos(x));

# %% [markdown]
# ## Change color
#
# Default color:
# ![default color](https://matplotlib.org/stable/_images/users-prev_whats_new-dflt_style_changes-1.2x.png)
#
# by specifying `color`

# %%
plt.plot(x, np.sin(x), color="red")
plt.plot(x, np.cos(x), color="green");

# %%
plt.plot(x, np.sin(x), color="C2")
plt.plot(x, np.cos(x), color="C4")

# %% [markdown]
# ## Change the line style and line width
#
# Set `linestyle, linewidth`
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %%
plt.plot(x, np.sin(x), color="red", linestyle="solid", linewidth=5)
plt.plot(x, np.cos(x), color="green", linestyle="dotted", linewidth=2);

# %% [markdown]
# ### Add markers
#
# Set `marker`
#
# https://matplotlib.org/stable/api/markers_api.html

# %%
x = np.linspace(0,10, 10)

# %%
plt.plot(x, np.sin(x), color="red", linestyle="dashed", linewidth=0.5, marker=".")
plt.plot(x, np.cos(x), color="green", linestyle="dotted", linewidth=0.5, marker="*");

# %% [markdown]
# Use `[marker][line][color]`

# %%
plt.plot(x, np.sin(x), ".--r")
plt.plot(x, np.cos(x), "*:g");

# %% [markdown]
# ## Axes limits
# `plt.xlim, plt.ylim`

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.xlim(-2, 12)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.xlim(0, 10)
plt.ylim(-1, 1)
plt.grid()

# %% [markdown]
# ## Labeling plots
#
# Use `plt.xlabel(), plt.ylabel(), plt.title()`, ...

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.xlabel("x")
plt.ylabel("sin/cos")
plt.title("sin/cos curves");

# %% [markdown]
# ### set `fontsize`

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.xlabel("x", fontsize=12)
plt.ylabel("sin/cos", fontsize=12)
plt.title("sin/cos curves", fontsize=18);

# %% [markdown]
# ## Legend

# %%
plt.plot(x, np.sin(x), label="sin")
plt.plot(x, np.cos(x), label="cos")
plt.xlabel("x", fontsize=12)
plt.ylabel("sin/cos", fontsize=12)
plt.title("sin/cos curves", fontsize=18)
plt.legend();

# %% [markdown]
# ### set `loc, ncol, fontsize`

# %%
plt.plot(x, np.sin(x), label="sin")
plt.plot(x, np.cos(x), label="cos")
plt.xlabel("x", fontsize=12)
plt.ylabel("sin/cos", fontsize=12)
plt.title("sin/cos curves", fontsize=18)
plt.legend(loc="upper center", ncol=2, fontsize=14);

# %%
plt.plot(x, np.sin(x), label="sin")
plt.plot(x, np.cos(x), label="cos")
plt.xlabel("x", fontsize=12)
plt.ylabel("sin/cos", fontsize=12)
plt.title("sin/cos curves", y = -0.3, fontsize=18)
plt.legend(loc="upper center", ncol=2, fontsize=14);

# %% [markdown]
# ## Scatter plot
#
# `plt.scatter(x, y, s=None, c=None, marker=None, cmap=None, alpha=None, linewidths=None, edgecolors=None,...)`

# %%
x = np.linspace(0, 10, 50)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x, np.sin(x), c="red", s=10, marker='>')
plt.scatter(x, np.cos(x), c="green", s=100, marker='s');

# %% [markdown]
# matplotlib supports various markers: https://matplotlib.org/stable/api/markers_api.html

# %%
x = np.random.random(50)
y = np.random.random(50)
colors = np.random.random(50)
sizes = 500*colors

# %% [markdown]
# When colors is a sequence of numbers (such as a numeric array), Matplotlib will automatically map those values to a colormap, which assigns colors to the points based on the range of values in the array.

# %%
plt.scatter(x, y, c=colors, s=sizes, alpha=0.6)
plt.colorbar();

# %%
df = pd.read_csv("iris.csv")
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.scatter(df["sepal_length"], df["sepal_width"],c=df["species"].astype("category").cat.codes, alpha=0.9)
plt.xlabel("sepal length")
plt.ylabel("sepal width");

# %% [markdown]
# Complete the above plot by adding the following:
# - legend for each species
# - title in the bottom

# %%
species = df["species"].unique()

# Plot each species separately
for i, species_name in enumerate(species):
    species_data = df[df["species"] == species_name]
    plt.scatter(species_data["sepal_length"], species_data["sepal_width"], 
                label=species_name, alpha=0.9)

# Label the axes and title
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Iris Dataset")

# Add legend
plt.legend(title="Species");

# %% [markdown]
# ## Bar plot
#
# Bar plots represent categorical data with rectangular bars where the height (or length for horizontal bars) is proportional to the values they represent.
#
# They are used to compare quantities across different categories.
#
# `plt.bar(), plt.barh()`

# %%
categories = ['A', 'B', 'C', 'D']
values = [4, 7, 1, 8]

# %%
plt.bar(categories, values);

# %%
plt.barh(categories, values);

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
avg_iris = df.groupby("species")["sepal_length"].mean()
avg_iris
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64

# %%
plt.barh(avg_iris.index, avg_iris);

# %%
avg_iris = df.groupby("species").mean()
avg_iris
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
width=0.2
multiplier=0
x = np.arange(3)
for i in range(avg_iris.shape[1]):
    offset = width*multiplier
    plt.bar(x + offset, avg_iris.iloc[:,i], width, label=avg_iris.columns[i])
    multiplier += 1
plt.legend()
plt.xticks(x + width, avg_iris.index);

# %% [markdown]
# ## Histograms
#
# Histograms are used to display the distribution of a dataset. They group data into bins and count how many data points fall into each bin.
#
# `plt.hist(x, bins=None, density=False, histtype='bar')`

# %%
x = np.random.normal(size=1000)

# %%
plt.hist(x);

# %%
plt.hist(x, bins=30);

# %% [markdown]
# What is the best value for bins?

# %%
plt.hist(x, bins=30, density=True); # y-scale become 1

# %%
plt.hist(x, bins=30, density=True, alpha=0.8);

# %% [markdown]
# We can also specify `histtype` which has four options `{'bar', 'barstacked', 'step', 'stepfilled'}`. The default is `'bar'`.

# %%
plt.hist(x, bins=30, density=True, alpha=0.5, histtype="stepfilled", edgecolor="black");

# %%
plt.hist(x, bins=30, density=True, cumulative=True, alpha=0.3, histtype="bar", edgecolor="black");

# %%
x1 = np.random.normal(0,1,size=1000)
x2 = np.random.normal(0,5, size=1000)
x3 = np.random.normal(-5, 1, size=1000)

# %%
for i in [x1, x2, x3]:
    plt.hist(i, bins=30, density=True, alpha=0.5);

# %%
X = np.vstack([x1, x2, x3]).T
X.shape
# Out:
# (1000, 3)

# %%
plt.hist(X, bins=100, density=True, alpha=0.5, histtype="barstacked");

# %% [markdown]
# ### Two-dimensional histogram
#
# `plt.hist2d()`

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=40)
plt.colorbar();

# %% [markdown]
# ## Boxplot
#
# Boxplots (or whisker plots) are used to display the distribution of data based on five-number summary: minimum, first quartile (Q1), median, third quartile (Q3), and maximum.
#
# They provide a visual way to identify outliers, spread, and skewness.
#
# `plt.boxplot(data, vert=True, patch_artist=False)`

# %%
x = np.random.random((6, 10))

# %%
plt.boxplot(x);

# %%
plt.boxplot(x, vert=False, patch_artist=True);

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.boxplot(df.iloc[:,:-1].values);
plt.xticks(range(1,5), df.columns[:-1]);

# %% [markdown]
# **Exercise 1**. Use the iris dataset to make plots.
#
# - Visualize the relationship between petal length and petal width for the three species of flowers
# - Use box plots to compare the distribution of sepal length for each Iris species.
# - Plot a histogram to compare the distribution of sepal lengths for each of the three species.

# %%
for color, label in zip(["C0", "C1", "C2"], df["species"].unique()):
    subset = df[df["species"] == label]
    plt.scatter(subset['petal_length'], subset['petal_length'], label = label, color = color)
plt.title("petal length vs petal width")
plt.xlabel("petal length")
plt.ylabel("petal width")
plt.legend(title="Species");

# %%
fig = plt.figure()
ax = plt.axes()
for i, label in enumerate(df["species"].unique()):
    subset = df[df["species"] == label]
    ax.boxplot(subset["sepal_length"], positions=[i])
ax.set_xticklabels(df["species"].unique());

# %%
fig = plt.figure()
ax = plt.axes()
for i, label in enumerate(df["species"].unique()):
    subset = df[df["species"] == label]
    ax.hist(subset["sepal_length"], bins=10, alpha=0.5, label=label)
plt.xlabel('Sepal length')
plt.ylabel("Number")
ax.legend();

# %% [markdown]
# ## Contour plot
#
# Contour lines represent different levels of a third variable (Z) over a grid defined by two variables (X and Y).
#
# `plt.contourf()`

# %%
x = y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2
plt.contourf(X, Y, Z, cmap=plt.cm.RdPu)
plt.axis('square');

# %%
Y
# Out:
# array([[-5.       , -5.       , -5.       , ..., -5.       , -5.       ,
#         -5.       ],
#        [-4.8989899, -4.8989899, -4.8989899, ..., -4.8989899, -4.8989899,
#         -4.8989899],
#        [-4.7979798, -4.7979798, -4.7979798, ..., -4.7979798, -4.7979798,
#         -4.7979798],
#        ...,
#        [ 4.7979798,  4.7979798,  4.7979798, ...,  4.7979798,  4.7979798,
#          4.7979798],
#        [ 4.8989899,  4.8989899,  4.8989899, ...,  4.8989899,  4.8989899,
#          4.8989899],
#        [ 5.       ,  5.       ,  5.       , ...,  5.       ,  5.       ,
#          5.       ]])

# %%
x = np.random.random((100,100))
plt.imshow(x);

# %%
x = y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2
plt.imshow(Z);

# %% [markdown]
# # Visualize uncertainty
#
# `plt.errorbar(x, y, yerr=None, xerr=None,...)`

# %%
x = np.linspace(0, 10, 20)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(20)

# %%
plt.errorbar(x, y, yerr=dy, fmt=".");

# %%
plt.errorbar(x, y, yerr=dy, fmt="o", color="black", ecolor="lightgray");

# %%
dx = 0.2

# %%
plt.errorbar(x, y, yerr=dy, xerr=dx, fmt="o", color="black", ecolor="darkgray");

# %% [markdown]
# ### `plt.fill_between`
#
# create a shaded region between two sets of y-values.
#
# `plt.fill_between(x, y1, y2)`

# %%
x = np.linspace(1,10,10)
y_mean = np.linspace(1, 10, 10)

y_upper = y_mean + 1.5
y_lower = y_mean - 1.5

# %%
plt.plot(x, y_mean, color="blue")
plt.fill_between(x, y_upper, y_lower, color="lightblue");
